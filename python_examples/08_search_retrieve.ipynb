# %% [markdown]
# # Search and retrieve
#
# Search for "platypus" and examine results.

# %%
# include some utility data and methods
import notebook_utils as nbu

import json
from d1_client import cnclient_2_0

cn_base_url = "https://cn.dataone.org/cn"
print("Using base url of: {0}\n".format(cn_base_url))

cncli = cnclient_2_0.CoordinatingNodeClient_2_0(base_url=cn_base_url)

query_engine = "solr"
base_path = "/"
term = "platypus"
query = f"text:%{term}% AND formatType:METADATA"
params = {
    "start":0,
    "count":10,
    "q":query,
    "wt":"json",
    "fl":"id,dateModified,dataSource,title,abstract"
}
res = cncli.queryResponse(query_engine, base_path, vendorSpecific=None, do_post=False, params=params)
print(f"URL sent to server: {res.url}")
results = json.loads(res.text)
print("Response JSON:")
print(nbu.nLines(json.dumps(results, indent=2), max_lines=50))
# Out:
# Using base url of: https://cn.dataone.org/cn
#
# URL sent to server: https://cn.dataone.org/cn/v2/query/solr/?start=0&count=10&q=text%3A%25platypus%25+AND+formatType%3AMETADATA&wt=json&fl=id%2CdateModified%2CdataSource%2Ctitle%2Cabstract
# Response JSON:
# {
#   "responseHeader": {
#     "status": 0,
#     "QTime": 4,
#     "params": {
#       "q": "text:%platypus% AND formatType:METADATA",
#       "fl": "id,dateModified,dataSource,title,abstract",
#       "start": "0",
#       "count": "10",
#       "wt": "json"
#     }
#   },
#   "response": {
#     "numFound": 68,
#     "start": 0,
#     "docs": [
#       {
#         "id": "AKCRRAB.8.1",
#         "dateModified": "2015-01-06T13:19:19.888Z",
#         "title": "2011 BKC larval rearing survival"
#       },
#       {
#         "id": "aekos.org.au/collection/tas.gov.au/platypus.20170511",
#         "dateModified": "2018-08-03T02:08:12.346Z",
#         "abstract": "The fungal disease mucormycosis, caused by the fungal pathogen Mucor amphibiorum, has infected Tasmanian platypus for almost three decades (Gust et al 2009, Gust and Griffiths, 2011). The disease causes skin lesions, morbidity and mortality (Gust and Griffiths, 2009). To investigate spatial and temporal distribution patterns of mucormycosis and its impacts on platypus, a database of extensive historic platypus capture and observation records was created. This data was used to map historic distribution and prevalence of mucormycosis. In 2008-2009 live trapping surveys were undertaken to determine the spread, prevalence and persistence of the disease. In addition, demographic (sex, age), morphometric (body size) and health and moult condition of captured individuals were assessed (Gust et al 2009, Gust and Griffiths, 2011). Furthermore, influences of mucormycosis on the hematology, plasma biochemistry and other indicators of health in platypus were investigated (Geraghty et al 2011). Please use the following URL to access the dataset: http://aekos.org.au/collection/tas.gov.au/platypus",
#         "title": "Platypus Survey Data, Tasmania (1901 - 2009)"
#       },
#       {
#         "id": "aekos.org.au/collection/tas.gov.au/platypus.20180628",
#         "dateModified": "2018-08-03T02:08:11.674Z",
#         "abstract": "The fungal disease mucormycosis, caused by the fungal pathogen Mucor amphibiorum, has infected Tasmanian platypus for almost three decades (Gust et al 2009, Gust and Griffiths, 2011). The disease causes skin lesions, morbidity and mortality (Gust and Griffiths, 2009). To investigate spatial and temporal distribution patterns of mucormycosis and its impacts on platypus, a database of extensive historic platypus capture and observation records was created. This data was used to map historic distribution and prevalence of mucormycosis. In 2008-2009 live trapping surveys were undertaken to determine the spread, prevalence and persistence of the disease. In addition, demographic (sex, age), morphometric (body size) and health and moult condition of captured individuals were assessed (Gust et al 2009, Gust and Griffiths, 2011). Furthermore, influences of mucormycosis on the hematology, plasma biochemistry and other indicators of health in platypus were investigated (Geraghty et al 2011). Please use the following URL to access the dataset: http://aekos.org.au/collection/tas.gov.au/platypus",
#         "title": "Platypus Survey Data, Tasmania (1901 - 2009)"
#       },
#       {
#         "id": "aekos.org.au/collection/tas.gov.au/platypus.20160201",
#         "dateModified": "2016-02-19T01:22:12.585Z",
#         "abstract": "The fungal disease mucormycosis, caused by the fungal pathogen Mucor amphibiorum, has infected Tasmanian platypus for almost three decades (Gust et al 2009, Gust and Griffiths, 2011). The disease causes skin lesions, morbidity and mortality (Gust and Griffiths, 2009). To investigate spatial and temporal distribution patterns of mucormycosis and its impacts on platypus, a database of extensive historic platypus capture and observation records was created. This data was used to map historic distribution and prevalence of mucormycosis. In 2008-2009 live trapping surveys were undertaken to determine the spread, prevalence and persistence of the disease. In addition, demographic (sex, age), morphometric (body size) and health and moult condition of captured individuals were assessed (Gust et al 2009, Gust and Griffiths, 2011). Furthermore, influences of mucormycosis on the hematology, plasma biochemistry and other indicators of health in platypus were investigated (Geraghty et al 2011). Please use the following URL to access the dataset: http://aekos.org.au/collection/tas.gov.au/platypus",
#         "title": "Platypus Survey Data, Tasmania (1901 - 2009)"
#       },
#       {
#         "id": "aekos.org.au/collection/tas.gov.au/platypus.20160628",
#         "dateModified": "2016-07-08T02:00:24.261Z",
#         "abstract": "The fungal disease mucormycosis, caused by the fungal pathogen Mucor amphibiorum, has infected Tasmanian platypus for almost three decades (Gust et al 2009, Gust and Griffiths, 2011). The disease causes skin lesions, morbidity and mortality (Gust and Griffiths, 2009). To investigate spatial and temporal distribution patterns of mucormycosis and its impacts on platypus, a database of extensive historic platypus capture and observation records was created. This data was used to map historic distribution and prevalence of mucormycosis. In 2008-2009 live trapping surveys were undertaken to determine the spread, prevalence and persistence of the disease. In addition, demographic (sex, age), morphometric (body size) and health and moult condition of captured individuals were assessed (Gust et al 2009, Gust and Griffiths, 2011). Furthermore, influences of mucormycosis on the hematology, plasma biochemistry and other indicators of health in platypus were investigated (Geraghty et al 2011). Please use the following URL to access the dataset: http://aekos.org.au/collection/tas.gov.au/platypus",
#         "title": "Platypus Survey Data, Tasmania (1901 - 2009)"
#       },
#       {
#         "id": "aekos.org.au/collection/tas.gov.au/platypus.20161121",
#         "dateModified": "2016-12-19T05:17:40.143Z",
#         "abstract": "The fungal disease mucormycosis, caused by the fungal pathogen Mucor amphibiorum, has infected Tasmanian platypus for almost three decades (Gust et al 2009, Gust and Griffiths, 2011). The disease causes skin lesions, morbidity and mortality (Gust and Griffiths, 2009). To investigate spatial and temporal distribution patterns of mucormycosis and its impacts on platypus, a database of extensive historic platypus capture and observation records was created. This data was used to map historic distribution and prevalence of mucormycosis. In 2008-2009 live trapping surveys were undertaken to determine the spread, prevalence and persistence of the disease. In addition, demographic (sex, age), morphometric (body size) and health and moult condition of captured individuals were assessed (Gust et al 2009, Gust and Griffiths, 2011). Furthermore, influences of mucormycosis on the hematology, plasma biochemistry and other indicators of health in platypus were investigated (Geraghty et al 2011). Please use the following URL to access the dataset: http://aekos.org.au/collection/tas.gov.au/platypus",
#         "title": "Platypus Survey Data, Tasmania (1901 - 2009)"
# ...

# %% [markdown]
# ## Resolve an item
#
# Use the `CN.resolve()` method to get the URL for the third item in the response.

# %%
identifier = results["response"]["docs"][2]["id"]
print(f"Resolving identifier: {identifier}")
res = cncli.resolve(identifier)
print(nbu.asXml(res))
# Out:
# Resolving identifier: aekos.org.au/collection/tas.gov.au/platypus.20180628
# <?xml version="1.0" ?>
# <ns1:objectLocationList xmlns:ns1="http://ns.dataone.org/service/types/v1">
#   <identifier>aekos.org.au/collection/tas.gov.au/platypus.20180628</identifier>
#   <objectLocation>
#     <nodeIdentifier>urn:node:CN</nodeIdentifier>
#     <baseURL>https://cn.dataone.org/cn</baseURL>
#     <version>v1</version>
#     <version>v2</version>
#     <url>https://cn.dataone.org/cn/v2/object/aekos.org.au%2Fcollection%2Ftas.gov.au%2Fplatypus.20180628</url>
#   </objectLocation>
#   <objectLocation>
#     <nodeIdentifier>urn:node:mnUNM1</nodeIdentifier>
#     <baseURL>https://mn-unm-1.dataone.org/knb/d1/mn</baseURL>
#     <version>v1</version>
#     <version>v2</version>
#     <url>https://mn-unm-1.dataone.org/knb/d1/mn/v2/object/aekos.org.au%2Fcollection%2Ftas.gov.au%2Fplatypus.20180628</url>
#   </objectLocation>
#   <objectLocation>
#     <nodeIdentifier>urn:node:TERN</nodeIdentifier>
#     <baseURL>https://dataone.tern.org.au/mn</baseURL>
#     <version>v1</version>
#     <version>v2</version>
#     <url>https://dataone.tern.org.au/mn/v2/object/aekos.org.au%2Fcollection%2Ftas.gov.au%2Fplatypus.20180628</url>
#   </objectLocation>
# </ns1:objectLocationList>
# ...

# %% [markdown]
# ## Retrieve the item
#
# Retrieve the item from the node and show the object.

# %%
doc = cncli.get(identifier)
print(doc.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <eml:eml packageId="aekos.org.au/collection/tas.gov.au/platypus.20180628" system="aekos" xmlns:acc="eml://ecoinformatics.org/access-2.1.1" xmlns:att="eml://ecoinformatics.org/attribute-2.1.1" xmlns:cit="eml://ecoinformatics.org/literature-2.1.1" xmlns:dat="eml://ecoinformatics.org/dataTable-2.1.1" xmlns:doc="eml://ecoinformatics.org/documentation-2.1.1" xmlns:ds="eml://ecoinformatics.org/dataset-2.1.1" xmlns:eml="eml://ecoinformatics.org/eml-2.1.1" xmlns:ent="eml://ecoinformatics.org/entity-2.1.1" xmlns:md="eml://ecoinformatics.org/methods-2.1.1" xmlns:phys="eml://ecoinformatics.org/physical-2.1.1" xmlns:proj="eml://ecoinformatics.org/project-2.1.1" xmlns:prot="eml://ecoinformatics.org/protocol-2.1.1" xmlns:rp="eml://ecoinformatics.org/party-2.1.1" xmlns:sp="eml://ecoinformatics.org/storedProcedure-2.1.1" xmlns:spref="eml://ecoinformatics.org/spatialReference-2.1.1" xmlns:sr="eml://ecoinformatics.org/spatialRaster-2.1.1" xmlns:sv="eml://ecoinformatics.org/spatialVector-2.1.1" xmlns:sw="eml://ecoinformatics.org/software-2.1.1" xmlns:txt="eml://ecoinformatics.org/text-2.1.1" xmlns:v="eml://ecoinformatics.org/view-2.1.1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
#     <dataset>
#         <title>Platypus Survey Data, Tasmania (1901 - 2009)</title>
#         <creator id="Department of Primary Industries, Parks, Water and Environment, Tasmania">
#             <organizationName>Department of Primary Industries, Parks, Water and Environment, Tasmania</organizationName>
#             <address>
#                 <deliveryPoint>Postal Address: GPO Box 44, HOBART Tasmania 7001</deliveryPoint>
#                 <deliveryPoint>Postal Address: GPO Box 44, HOBART Tasmania 7001</deliveryPoint>
#                 <deliveryPoint>Davies Building, Waite Campus, University of Adelaide</deliveryPoint>
#                 <city>Adelaide</city>
#                 <postalCode>5005</postalCode>
#                 <country>Australia</country>
#             </address>
#             <phone>+61 3 6165 4328</phone>
#             <electronicMailAddress>support&amp;#64;naturalvaluesatlas.tas.gov.au</electronicMailAddress>
#         </creator>
#         <pubDate>2015</pubDate>
#         <abstract>The fungal disease mucormycosis, caused by the fungal pathogen Mucor amphibiorum, has infected Tasmanian platypus for almost three decades (Gust et al 2009, Gust and Griffiths, 2011). The disease causes skin lesions, morbidity and mortality (Gust and Griffiths, 2009). To investigate spatial and temporal distribution patterns of mucormycosis and its impacts on platypus, a database of extensive historic platypus capture and observation records was created. This data was used to map historic distribution and prevalence of mucormycosis. In 2008-2009 live trapping surveys were undertaken to determine the spread, prevalence and persistence of the disease. In addition, demographic (sex, age), morphometric (body size) and health and moult condition of captured individuals were assessed (Gust et al 2009, Gust and Griffiths, 2011). Furthermore, influences of mucormycosis on the hematology, plasma biochemistry and other indicators of health in platypus were investigated (Geraghty et al 2011). Please use the following URL to access the dataset: http://aekos.org.au/collection/tas.gov.au/platypus</abstract>
#         <keywordSet>
#             <keyword>Species Presence/Abundance</keyword>
#             <keyword>Fauna</keyword>
#             <keyword>Specimens</keyword>
#         </keywordSet>
#         <intellectualRights>&amp;#169; 2015 State of Tasmania (Department of Primary Industries, Parks, Water and Environment). Rights owned by the State of Tasmania (Department of Primary Industries, Parks, Water and Environment). Rights licensed subject to Creative Commons - Attribution 3.0 Australia. Data Licence v1.0. Please use the following format when citing this dataset: Department of Primary Industries, Parks, Water and Environment (2015). Platypus Survey Data, Tasmania (1901 - 2009), Version 4/2015. Persistent URL: http://www.aekos.org.au/collection/tas.gov.au/platypus. TERN AEKOS, rights owned by the State of Tasmania (Department of Primary Industries, Parks, Water and Environment). Accessed [dd mmm yyyy, e.g. 01 Jan 2016].</intellectualRights>
#         <distribution>
#             <online>
#                 <url>http://aekos.org.au/collection/tas.gov.au/platypus</url>
#             </online>
#         </distribution>
#         <coverage>
#             <geographicCoverage>
#                 <geographicDescription>Tasmanian waterways.</geographicDescription>
#                 <boundingCoordinates>
#                     <westBoundingCoordinate>143.870601849308</westBoundingCoordinate>
#                     <eastBoundingCoordinate>148.266757140061</eastBoundingCoordinate>
#                     <northBoundingCoordinate>-39.7484281733647</northBoundingCoordinate>
#                     <southBoundingCoordinate>-43.4986067556481</southBoundingCoordinate>
#                 </boundingCoordinates>
#             </geographicCoverage>
#             <taxonomicCoverage>
#                 <taxonomicClassification>
#                     <taxonRankValue>Ornithorhynchus anatinus</taxonRankValue>
#                 </taxonomicClassification>
#             </taxonomicCoverage>
#             <temporalCoverage>
#                 <rangeOfDates>
#                     <beginDate>
#                         <calendarDate>1901-01-01</calendarDate>
#                     </beginDate>
#                     <endDate>
#                         <calendarDate>2009-09-12</calendarDate>
#                     </endDate>
#                 </rangeOfDates>
#             </temporalCoverage>
#         </coverage>
#         <contact>
#             <organizationName>Department of Primary Industries, Parks, Water and Environment, Tasmania</organizationName>
#             <phone>+61 3 6165 4328</phone>
#             <electronicMailAddress>support&amp;#64;naturalvaluesatlas.tas.gov.au</electronicMailAddress>
#         </contact>
#         <publisher>
#             <organizationName>TERN Eco-informatics</organizationName>
#             <phone>+61 8 8313 1145</phone>
#             <electronicMailAddress>esupport@tern.org.au</electronicMailAddress>
#         </publisher>
#         <methods>
#             <methodStep>
#                 <description>Study Location Selection: Study locations for the Tasmanian Platypus Survey were selected a) by defining the spatial scale of interest to assess the distribution of the fungal disease 'mucormycosis' and b) by creating a comprehensive database of platypus records in Tasmania to quantify the spatial and temporal distribution and prevalence of platypus mucormycosis across Tasmania (Gust et al 2009). Mucormycosis is caused by the fungus Macur amphibiorum, previously isolated from frogs and toads, however also infects free-living platypus in rivers in Tasmania. The fungus is responsible for the severe ulcerative skin condition in platypus (Munday and Peel 1983, Obendorf et al 1993). The spatial scale of interest for fungal disease assessment has been defined as individual river catchments in Tasmania and King Island in Brass Straight. These river catchments are discrete management and conservation units, and contain a network of interconnecting water bodies, where platypus can potentially interact and breed. Catchment boundaries around Tasmania's 48 planning and management river catchments are defined by Land Information Service Tasmania at the Department of Primary Industries, Parks, Water and Environment. The database of historic platypus mucormycosis records in Tasmania was established using a wide variety of sources, including published scientific literature, museum records and public observations.Catchment disease status classification method: Historically disease affected catchments are identified for trapping surveys.Catchments were classified into four qualitative disease status categories according to available evidence based on desktop assessment of historical data and public sightings. Animal capture: Live trapping surveys are conducted across Tasmania to quantify patterns of natural spatial and seasonal variation in the morphometric and demographic characteristics of platypuses and to determine the spread, prevalence and persistence of the ulcerative fungal disease mucormycosis in Tasmanian platypus.Live trapping surveys are conducted in 18 Tasmanian river catchments and 75 waterways between January 2008 and June 2009. The sampling strategy concentrates effort in nine historically affected catchments, five possibly affected catchments, and four catchments outside the known distribution of mucormycosis, including King Island. Sampling effort within catchments is spread across multiple waterways. King Island in Brass Straight is also surveyed in January 2009 because its small, isolated platypus population may be particularly vulnerable to mucormycosis due to low genetic diversity. Animal processing:To quantify patterns of natural spatial and seasonal variation in the morphometric and demographic characteristics of platypuses and to determine the spread, prevalence and persistence of the ulcerative fungal disease mucormycosis in platypus. Morphometric and demographic patterns in Tasmania platypuses caught during the live trapping survey in 2008-09 are examined to provide a basis for investigating impacts of mucormycosis or other anthropogenic disturbances. Additionally, important spatial scales of natural variability and the magnitude of seasonal variation in platypus body size, condition, health and population structure are identified. Captured animals are processed 30 min of retrieval from nets and released at the capture location immediately after processing. Animal blood parameter analysis: 1. To determine the association between mucormycosis in Tasmanian platypuses and hematologic and biochemical measures, trypanosome infections, altitude and other parameters. 2. To compare hematologic and plasma biochemical measures of free-ranging Tasmanian platypuses in river catchments grouped by their mucormycosis disease status. 3. Establish robust reference intervals for some hematologic and biochemical measures in free-living platypuses. Broad spectrum haematological and parasite load analysis are  ...
#             </methodStep>
#         </methods>
#         <project>
#             <title>Platypus Survey Data, Tasmania (1901 - 2009)</title>
#             <personnel>
#                 <organizationName>Department of Primary Industries, Parks, Water and Environment, Tasmania</organizationName>
#                 <role>originator</role>
#             </personnel>
#             <personnel>
#                 <organizationName>the State of Tasmania (Department of Primary Industries, Parks, Water and Environment)</organizationName>
#                 <role>owner</role>
#             </personnel>
#         </project>
#     </dataset>
# </eml:eml>
