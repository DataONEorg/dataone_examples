% %% [markdown]
% # Matlab DataONE client
%
% The Matlab DataONE Toolbox collects information about Matlab script executions (aka runs). The captured information includes the files that were read and written by the Matlab script, and details of the execution environment, such as the operating system version, toolboxes loaded, etc.
%
% The recorded information for a script constitutes data provenance for the data products and analysis outputs (graphs, .csv files, etc) generated by a script execution, by providing information to describe how the data products were created.

% %% [markdown]
% ## Recording a script execution
% The RunManager.record() method takes a Matlab script as an argument and evals it, recording files that were read and written by Matlab functions that are registered with the Matlab DataONE toobox. It is not necessary to modify a Matlab script in order to use record(). You can also add a string to tag the run for reference.
%
% Note that the data used in this document is available from the DataONE git repository at
% https://github.com/DataONEorg/matlab-dataone/tree/master/src/test/resources.
%
% The following example initializes the RunManager and then runs a sample script:

% %%
import org.dataone.client.run.RunManager;
mgr = RunManager.getInstance();

% %%
cd '~/Documents/C3_C4_mapping'
mgr.record('C3_C4_map_present_NA_with_comments.m', 'Test_run_matlab_jupyter_3');
% Out:
%  INFO [main] (CertificateManager.java:1080) - selectSession: using the default certificate location
%  INFO [main] (CertificateManager.java:1091) - Did not find a certificate for the subject specified: null
%  INFO [main] (CertificateManager.java:806) - ...trying SSLContext protocol: TLSv1.2
%  INFO [main] (CertificateManager.java:808) - ...setting SSLContext with protocol: TLSv1.2
%  INFO [main] (CertificateManager.java:956) - creating custom TrustManager
%  INFO [main] (CertificateManager.java:365) - loading into client truststore: java.io.InputStreamReader@5d95b457
%  INFO [main] (CertificateManager.java:376) - 0 alias CN=DataONE Root CA,DC=dataone,DC=org
%  INFO [main] (CertificateManager.java:376) - 1 alias CN=DataONE Production CA,DC=dataone,DC=org
%  INFO [main] (CertificateManager.java:376) - 2 alias CN=CILogon Basic CA 1,O=CILogon,C=US,DC=cilogon,DC=org
%  INFO [main] (CertificateManager.java:376) - 3 alias CN=CILogon OpenID CA 1,O=CILogon,C=US,DC=cilogon,DC=org
% ...

% %% [markdown]
% ## Listing script executions
% Information about the script execution is stored in the Matlab DataONE toolbox cache (~/.d1). The toolbox provides methods to search, view, modify and publish items stored in the cache. It is not recommended that files or directories be manually edited or deleted from the cache directories, with the exception of the items mentioned in this document.

% %%
mgr.listRuns();
% Out:
%     runNumber                  packageId                                 scriptName                              tag                    startDate             endDate         publishDate
%     _________    ______________________________________    ______________________________________    ___________________________    _________________    _________________    ___________
%
%     '16'         '74842e39-423b-480e-9302-bbe5070210fa'    'C3_C4_map_present_NA_with_comments.m'    'Test_run_matlab_jupyter_4'    '20170427T141805'    '20170427T141812'    ''
%     '1'          '196d7ad2-8758-41b4-a660-5ad1d74e806b'    'C3_C4_map_present_NA_with_comments.m'    'Test_run_matlab_jupyter_3'    '20170427T143707'    '20170427T143714'    ''

% %% [markdown]
% ## Viewing Script Executions
%
% More detailed information can be retrieved and viewed for a run using the RunManager.view() function. To view a given run, pass in the runNumber or packageId from one of the resulting rows from the output of listRuns(). For instance:

% %%
mgr.view('runNumber', 1, 'sections', {'details', 'used', 'generated'});
% Out:
% ...
%
% [DETAILS]: Run details
% -------------------------
% "C3_C4_map_present_NA_with_comments" was executed on 2017-04-27 14:37:07
%                         Tag: 'Test_run_matlab_jupyter_3'
%           RunSequenceNumber: '1'
%               PublishedDate: 'Not Published'
%                 PublishedTo: 'urn:node:mnTestKNB'
%                   RunByUser: 'slaughter'
%              AccountSubject: ''
%                       RunId: '196d7ad2-8758-41b4-a660-5ad1d74e806b'
%               DataPackageId: '196d7ad2-8758-41b4-a660-5ad1d74e806b'
%                      HostId: 'Peters-MacBook-Pro.local'
%             OperatingSystem: 'Mac OS X  Version: 10.12.3 Build: 16D32'
%                     Runtime: 'MATLAB 9.1 (R2016b) 25-Aug-2016'
%                Dependencies: '/Users/slaughter/git/DataONEorg/matlab-datao...'
%                RunStartTime: '2017-04-27 14:37:07'
%               RunEndingTime: '2017-04-27 14:37:14'
%     ErrorMessageFromThisRun: ''
%
%
%
% [USED]: 25 Items used by this run
% ...

% %% [markdown]
% ## Publishing an execution
% The toolbox can package and publish data and metadata generated by a script execution to a registered DataONE repository. For scientists to understand the data generated by the run, a certain amount of metadata needs to be provided.
%
% Basic metadata are generated for each run. The toolbox provides a template metadata file that will be populated with preset configuration properties. As an example, by setting the following RunManager.configuration values, each metadata document for a run will contain these values:

% %%
set(mgr.configuration, 'target_member_node_id', 'urn:node:mnTestKNB');
set(mgr.configuration, 'source_member_node_id', 'urn:node:mnTestKNB');
set(mgr.configuration, 'coordinating_node_base_url', 'https://cn-stage-2.test.dataone.org/cn');
set(mgr.configuration, 'authentication_token', 'eyJhbGciOiJSUzI1NiJ9..Cct_cuMfeGDenga3tX-yBuix2LMEAk7XbQw6MJihNFubyS1QO8YO272KZBjikudrt1mqOxX8ERYw7RgLptbWOrKZ45E5gllYknVP8sUPZpLSykUgDJakbWHLwYjPfwif-w_CAQP56tgWCqc_I3j53JOBUZO6H_ZM3OnhEmdGaoVDOYwt52_6tRRnkl6wRLwnSyLvs66PQczUDpFVpKNAPRkNKoyc9MqlgGZIchEUpkLFgfXIXTeCXNWs9BLNOlS__kyeLk-lEAm31COHa_Odi82OVlf1C_nBwe4RszV864dK1kQQI1ykwI8w5JndME64GtHXnL_hJ1Wj4tb1j7oTP3hJmtBwiJu49HjbC8fpSK-2hAgErGAHDRGRwrOkmRCDcNPcZglGYzjoIl3KCNsW7u3F4kT13N7MgK9DGx_V8euZ1PF0Xfdx1dmUeKUwQW-T0gvipSFstfLRcVmoIKsmi86AWH5jW3JVLplOArrOk1aFt4iqkmzON2Xeab46R8qE3z0f8rqeFWYr7J3lZdLzPJDu9Nf3lkZVAA5-u4KzUFqCbyMMLtzOWRjpF7i_gd8-C_SLWPiMxJOwxlymVPTof5ftBwMvpl79j6eeFu6Ec8jxhGbZMdnneAcfUQWFKKzoDjdlT39CvsGwefGsINuSLXT02uNWzaCTBmEwhaZ7vIg');

mgr.publish('196d7ad2-8758-41b4-a660-5ad1d74e806b');
% Out:
%  INFO [main] (RestClient.java:234) - rest call info: GET https://cn-stage-2.test.dataone.org/cn/v2/node
%  INFO [main] (ExceptionHandler.java:93) - response httpCode: 200
% ...
% Uploading to : https://dev.nceas.ucsb.edu/knb/d1/mn/v2/object/012e8426-4b3e-4c81-9c32-2059418d4f2b
% File format  : netCDF-3
% File path    : /Users/slaughter/Documents/C3_C4_mapping/inputs/narr_air.2m_monthly/air.2m_monthly_2000_2010_mean.2.nc
%  INFO [main] (RestClient.java:276) - rest call info: POST https://cn-stage-2.test.dataone.org/cn/v2/reserve; MMP message has: ParamPart:pid = 012e8426-4b3e-4c81-9c32-2059418d4f2b;
%  INFO [main] (ExceptionHandler.java:93) - response httpCode: 200
%  INFO [main] (SimpleMultipartEntity.java:211) - temp outputFile is: /var/folders/zb/y107bkgx6l90vc199ff_zx2r0000gn/T/mmp.output.1339478375421140530.tmp
%  INFO [main] (SimpleMultipartEntity.java:211) - temp outputFile is: /var/folders/zb/y107bkgx6l90vc199ff_zx2r0000gn/T/mmp.output.5095056573589197678.tmp
% ...

% %% [markdown]
% ## Deleting an execution
%
% If a run wasn't useful, you can delete one or more runs from the database using the deleteRuns() function.

% %%
mgr.deleteRuns('runNumber', 16)
% Out:
% The /Users/slaughter/.d1/provenance/runs/74842e39-423b-480e-9302-bbe5070210fa directory to be deleted not exist.
%
% ans =
%
%   1�16 cell array
%
%   Columns 1 through 3
%
%     '74842e39-423b-48...'    '/Users/slaughter...'    '20170427T141805'
%
%   Columns 4 through 7
%
%     '20170427T141812'    ''    '74842e39-423b-48...'    'Test_run_matlab_...'
%
%   Columns 8 through 11
%
%     'slaughter'    ''    'Peters-MacBook-P...'    'Mac OS X  Versio...'
%
%   Columns 12 through 16
%
%     'MATLAB 9.1 (R201...'    '/Users/slaughter...'    ''    ''    '16'
