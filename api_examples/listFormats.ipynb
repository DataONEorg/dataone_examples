# %% [markdown]
# # List Formats
#
# List the formatIds registered in DataONE using the listFormts method.

# %%
# include some utility data and methods
# %run utilities.ipynb

# Import the library and create a client instance
from d1_client import cnclient_2_0

cn_base_url = "https://cn.dataone.org/cn"
client = cnclient_2_0.CoordinatingNodeClient_2_0(base_url=cn_base_url)

formats = client.listFormats()

print(asXml(formats))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <ns1:objectFormatList count="134" start="0" total="134" xmlns:ns1="http://ns.dataone.org/service/types/v2.0">
#   <objectFormat>
#     <formatId>eml://ecoinformatics.org/eml-2.0.0</formatId>
#     <formatName>Ecological Metadata Language, version 2.0.0</formatName>
#     <formatType>METADATA</formatType>
#     <mediaType name="text/xml"/>
#     <extension>xml</extension>
#   </objectFormat>
#   <objectFormat>
#     <formatId>eml://ecoinformatics.org/eml-2.0.1</formatId>
#     <formatName>Ecological Metadata Language, version 2.0.1</formatName>
#     <formatType>METADATA</formatType>
#     <mediaType name="text/xml"/>
#     <extension>xml</extension>
#   </objectFormat>
#   <objectFormat>
#     <formatId>eml://ecoinformatics.org/eml-2.1.0</formatId>
#     <formatName>Ecological Metadata Language, version 2.1.0</formatName>
#     <formatType>METADATA</formatType>
#     <mediaType name="text/xml"/>
#     <extension>xml</extension>
#   </objectFormat>
#   <objectFormat>
#     <formatId>eml://ecoinformatics.org/eml-2.1.1</formatId>
# ...

# %%
for fmt in formats.objectFormat:
    print(fmt.formatId)
    print(f"  {fmt.formatType}")
    media_type = ""
    if fmt.mediaType is not None:
        media_type = fmt.mediaType.name
    ext = ""
    if fmt.extension is not None:
        ext = fmt.extension
    print(f"  {ext:4} {media_type}")
    print(f"  {fmt.formatName}")
# Out:
# eml://ecoinformatics.org/eml-2.0.0
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, version 2.0.0
# eml://ecoinformatics.org/eml-2.0.1
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, version 2.0.1
# eml://ecoinformatics.org/eml-2.1.0
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, version 2.1.0
# eml://ecoinformatics.org/eml-2.1.1
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, version 2.1.1
# https://eml.ecoinformatics.org/eml-2.2.0
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, version 2.2.0
# http://www.esri.com/metadata/esriprof80.dtd
#   METADATA
#   xml  text/xml
#   ESRI Profile of the Content Standard for Digital Geospatial Metadata, March 2003
# FGDC-STD-001.1-1999
#   METADATA
#   xml  text/xml
#   Content Standard for Digital Geospatial Metadata, Biological Data Profile, version 001.1-1999
# FGDC-STD-001.2-1999
#   METADATA
#   xml  text/xml
#   Content Standard for Digital Geospatial Metadata, Metadata Profile for Shoreline Data, version 001.2-1999
# FGDC-STD-001-1998
#   METADATA
#   xml  text/xml
#   Content Standard for Digital Geospatial Metadata, version 001-1998
# INCITS-453-2009
#   METADATA
#   xml  text/xml
#   North American Profile of ISO 19115: 2003 Geographic Information - Metadata
# http://www.unidata.ucar.edu/namespaces/netcdf/ncml-2.2
#   METADATA
#   nc   application/netcdf
#   NetCDF Markup Language, version 2.2
# CF-1.0
#   DATA
#   nc   application/netcdf
#   NetCDF Climate and Forecast Metadata Convention, version 1.0
# CF-1.1
#   DATA
#   nc   application/netcdf
#   NetCDF Climate and Forecast Metadata Convention, version 1.1
# CF-1.2
#   DATA
#   nc   application/netcdf
#   NetCDF Climate and Forecast Metadata Convention, version 1.2
# CF-1.3
#   DATA
#   nc   application/netcdf
#   NetCDF Climate and Forecast Metadata Convention, version 1.3
# CF-1.4
#   DATA
#   nc   application/netcdf
#   NetCDF Climate and Forecast Metadata Convention, version 1.4
# http://www.cuahsi.org/waterML/1.0/
#   METADATA
#   xml  text/xml
#   Water Markup Language, version 1.0
# http://www.cuahsi.org/waterML/1.1/
#   METADATA
#   xml  text/xml
#   Water Markup Language, version 1.0
# http://www.loc.gov/METS/
#   METADATA
#   xml  text/xml
#   Metadata Encoding and Transmission Standard, version 1
# netCDF-3
#   DATA
#   nc   application/netcdf
#   Network Common Data Format, version 3
# netCDF-4
#   DATA
#   nc   application/netcdf
#   Network Common Data Format, version 4
# text/plain
#   DATA
#   txt  text/plain
#   Plain Text
# text/csv
#   DATA
#   csv  text/csv
#   Comma Separated Values Text
# image/bmp
#   DATA
#   bmp  image/bmp
#   Bitmap Image File
# image/gif
#   DATA
#   gif  image/gif
#   Graphics Interchange Format
# image/jp2
#   DATA
#   jpg  image/jp2
#   JPEG 2000
# image/jpeg
#   DATA
#   jpg  image/jpeg
#   JPEG
# image/png
#   DATA
#   png  image/png
#   Portable Network Graphics
# image/svg+xml
#   DATA
#   svg  image/svg+xml
#   Scalable Vector Graphics
# image/tiff
#   DATA
#   tiff image/tiff
#   Tagged Image File Format
# http://rs.tdwg.org/dwc/xsd/simpledarwincore/
#   METADATA
#   xml  text/xml
#   Simple Darwin Core
# http://digir.net/schema/conceptual/darwin/2003/1.0/darwin2.xsd
#   METADATA
#   xml  text/xml
#   Darwin Core, version 2.0
# application/octet-stream
#   DATA
#   data application/octet-stream
#   Octet Stream
# http://www.w3.org/2005/Atom
#   DATA
#   atom application/atom+xml
#   ATOM-1.0
# text/n3
#   DATA
#   rdf  text/n3
#   N3
# text/turtle
#   DATA
#   ttl  text/turtle
#   TURTLE
# application/rdf+xml
#   DATA
#   rdf  application/rdf+xml
#   Resource Description Framework
# http://www.w3.org/TR/rdf-testcases/#ntriples
#   DATA
#   nt   text/plain
#   N-TRIPLE
# http://www.w3.org/TR/rdf-syntax-grammar
#   DATA
#   rdf  application/rdf+xml
#   RDF/XML
# http://www.w3.org/TR/rdfa-syntax
#   DATA
#   xhtml application/xhtml+xml
#   RDFa
# http://www.openarchives.org/ore/terms
#   RESOURCE
#   rdf  application/rdf+xml
#   Object Reuse and Exchange Vocabulary
# application/pdf
#   DATA
#   pdf  application/pdf
#   Portable Document Format
# http://datadryad.org/profile/v3.1
#   METADATA
#   xml  text/xml
#   Dryad Metadata Application Profile Version 3.1
# http://purl.org/dryad/terms/
#   METADATA
#   xml  text/xml
#   Dryad Metadata Application Profile Version 3.0
# application/vnd.ms-excel
#   DATA
#   xls  application/vnd.ms-excel
#   Microsoft Excel file format
# application/msword
#   DATA
#   doc  application/msword
#   Microsoft Word file format
# anvl/erc-v02
#   DATA
#   anvl text/anvl
#   Kernel Metadata and Electronic Resource Citations (ERCs), 2010.05.13
# nexus/1997
#   DATA
#   nxs  text/plain
#   NEXUS File Format for Systematic Information
# application/zip
#   DATA
#   zip  application/zip
#   Zip file format
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet
#   DATA
#   xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet
#   Microsoft Excel OpenXML
# application/vnd.openxmlformats-officedocument.wordprocessingml.document
#   DATA
#   docx application/vnd.openxmlformats-officedocument.wordprocessingml.document
#   Microsoft Word OpenXML
# application/x-fasta
#   DATA
#   fasta application/x-fasta
#   FASTA sequence file
# text/xml
#   DATA
#   xml  text/xml
#   Extensible Markup Language
# application/xml
#   DATA
#   xml  application/xml
#   Extensible Markup Language Application
# application/rtf
#   DATA
#   rtf  application/rtf
#   Rich Text Format
# text/html
#   DATA
#   html text/html
#   Hypertext Markup Language
# application/postscript
#   DATA
#   ps   application/postscript
#   Postscript
# audio/x-wav
#   DATA
#   wav  audio/x-wav
#   Wave Audio Format
# application/mathematica
#   DATA
#   nb   application/mathematica
#   Mathematica Notebook
# video/quicktime
#   DATA
#   mov  video/quicktime
#   Quicktime Video
# application/x-gzip
#   DATA
#   gz   application/x-gzip
#   GZIP Format
# application/x-python
#   DATA
#   py   text/x-python
#   Python programming language script
# video/x-ms-wmv
#   DATA
#   wmv  video/x-ms-wmv
#   Windows Media Video File
# audio/x-ms-wma
#   DATA
#   wma  audio/x-ms-wma
#   Windows Media Audio File
# video/avi
#   DATA
#   avi  video/avi
#   Microsoft Audio Video Interleave (AVI) File
# video/mpeg
#   DATA
#   mpg  video/mpeg
#   MPEG-1 Video
# audio/mpeg
#   DATA
#   mp3  audio/mpeg
#   MPEG-1 or MPEG-2 Audio Layer III
# video/mp4
#   DATA
#   mp4  video/mp4
#   MPEG-4 Video
# application/x-tar
#   DATA
#   tar  application/x-tar
#   Tape Archive File
# application/x-bzip2
#   DATA
#   zip  application/x-bzip2
#   Bzip2 Compressed File
# application/vnd.google-earth.kml+xml
#   DATA
#   kml  application/vnd.google-earth.kml+xml
#   Google Earth Keyhole Markup Language (KML)
# application/x-rar-compressed
#   DATA
#   rar  application/x-rar-compressed
#   Roshal Archive File
# application/vnd.ms-excel.sheet.binary.macroEnabled.12
#   DATA
#   xls  application/vnd.ms-excel.sheet.binary.macroEnabled.12
#   Microsoft Office Excel 2007 binary workbooks
# application/vnd.ms-powerpoint
#   DATA
#   ppt  application/vnd.ms-powerpoint
#   Microsoft Office Powerpoint
# application/vnd.openxmlformats-officedocument.presentationml.presentation
#   DATA
#   pptx application/vnd.openxmlformats-officedocument.presentationml.presentation
#   Microsoft Office OpenXML Presentation
# -//ecoinformatics.org//eml-access-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Access module, version 2.0.0beta4
# -//ecoinformatics.org//eml-attribute-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Attribute module, version 2.0.0beta4
# -//ecoinformatics.org//eml-constraint-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Constraint module, version 2.0.0beta4
# -//ecoinformatics.org//eml-coverage-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Coverage module, version 2.0.0beta4
# -//ecoinformatics.org//eml-dataset-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Dataset module, version 2.0.0beta4
# -//ecoinformatics.org//eml-distribution-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Distribution module, version 2.0.0beta4
# -//ecoinformatics.org//eml-entity-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Entity module, version 2.0.0beta4
# -//ecoinformatics.org//eml-literature-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Literature module, version 2.0.0beta4
# -//ecoinformatics.org//eml-party-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Party module, version 2.0.0beta4
# -//ecoinformatics.org//eml-physical-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Physical module, version 2.0.0beta4
# -//ecoinformatics.org//eml-project-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Project module, version 2.0.0beta4
# -//ecoinformatics.org//eml-protocol-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Protocol module, version 2.0.0beta4
# -//ecoinformatics.org//eml-resource-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Resource module, version 2.0.0beta4
# -//ecoinformatics.org//eml-software-2.0.0beta4//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Software module, version 2.0.0beta4
# -//ecoinformatics.org//eml-access-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Access module, version 2.0.0beta6
# -//ecoinformatics.org//eml-attribute-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Attribute module, version 2.0.0beta6
# -//ecoinformatics.org//eml-constraint-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Constraint module, version 2.0.0beta6
# -//ecoinformatics.org//eml-coverage-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Coverage module, version 2.0.0beta6
# -//ecoinformatics.org//eml-dataset-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Dataset module, version 2.0.0beta6
# -//ecoinformatics.org//eml-distribution-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Distribution module, version 2.0.0beta6
# -//ecoinformatics.org//eml-entity-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Entity module, version 2.0.0beta6
# -//ecoinformatics.org//eml-literature-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Literature module, version 2.0.0beta6
# -//ecoinformatics.org//eml-party-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Party module, version 2.0.0beta6
# -//ecoinformatics.org//eml-physical-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Physical module, version 2.0.0beta6
# -//ecoinformatics.org//eml-project-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Project module, version 2.0.0beta6
# -//ecoinformatics.org//eml-protocol-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Protocol module, version 2.0.0beta6
# -//ecoinformatics.org//eml-resource-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Resource module, version 2.0.0beta6
# -//ecoinformatics.org//eml-software-2.0.0beta6//EN
#   METADATA
#   xml  text/xml
#   Ecological Metadata Language, Software module, version 2.0.0beta6
# ddi:codebook:2_5
#   METADATA
#   xml  text/xml
#   Data Documentation Initiative, Codebook version 2.5
# http://www.icpsr.umich.edu/DDI
#   METADATA
#   xml  text/xml
#   Data Documentation Initiative, Codebook version 2.1
# http://purl.org/ornl/schema/mercury/terms/v1.0
#   METADATA
#   xml  text/xml
#   Oak Ridge National Lab Mercury Metadata version 1.0
# http://datacite.org/schema/kernel-3.0
#   METADATA
#   xml  text/xml
#   DataCite Metadata Schema version 3.0
# http://datacite.org/schema/kernel-3.1
#   METADATA
#   xml  text/xml
#   DataCite Metadata Schema version 3.1
# http://www.nexml.org/2009
#   DATA
#   xml  text/xml
#   NeXML 2009
# http://ns.dataone.org/metadata/schema/onedcx/v1.0
#   METADATA
#   xml  text/xml
#   DataONE Dublin Core Extended v1.0
# http://docs.annotatorjs.org/en/v1.2.x/annotation-format.html
#   RESOURCE
#   json application/json
#   AnnotatorJS 1.2.x Annotation model
# http://www.isotc211.org/2005/gmd
#   METADATA
#   xml  text/xml
#   Geographic MetaData (GMD) Extensible Markup Language
# http://www.isotc211.org/2005/gmd-noaa
#   METADATA
#   xml  text/xml
#   NOAA Variant Geographic MetaData (GMD) Extensible Markup Language
# http://www.isotc211.org/2005/gmd-pangaea
#   METADATA
#   xml  text/xml
#   PANGAEA Variant Geographic MetaData (GMD) Extensible Markup Language
# application/bagit-097
#   DATA
#
#   BagIt File Packaging Format Version 0.97
# text/tsv
#   DATA
#   tsv  text/tab-separated-values
#   Tab Separated Values Text
# application/R
#   DATA
#   R    text/x-rsrc
#   R programming language script
# application/MATLAB
#   DATA
#   m    text/x-matlab
#   MATLAB programming language script
# application/SAS
#   DATA
#   sas  text/x-sas
#   SAS programming language script
# application/vnd.google-earth.kmz
#   DATA
#   kmz  application/vnd.google-earth.kmz
#   Google Earth Keyhole Markup Language (KML) Compressed archive
# application/MATLAB-v7.3
#   DATA
#   mat  application/octet-stream
#   Mathworks MATLAB version 7.3 (R2006b or later) binary file - HDF5 compatible
# application/MATLAB-v7
#   DATA
#   mat  application/octet-stream
#   Mathworks MATLAB version 7 (R14 or later) binary file
# application/MATLAB-v6
#   DATA
#   mat  application/octet-stream
#   Mathworks MATLAB version 6 (R8 or later) binary file
# application/MATLAB-v4
#   DATA
#   mat  application/octet-stream
#   Mathworks MATLAB version 4 binary file
# application/json
#   DATA
#   json application/json
#   JavaScript Object Notation (JSON) file
# application/json-ld
#   DATA
#   json application/ld+json
#   JavaScript Object Notation (JSON) Linked Data file
# text/markdown
#   DATA
#   md   text/markdown
#   Markdown file (pandoc markdown compatible)
# text/x-rmarkdown
#   DATA
#   Rmd  text/markdown
#   R Markdown file (pandoc markdown compatible)
# image/x-raw
#   DATA
#   raw  application/octet-stream
#   RAW digital sensor image file
# http://www.openarchives.org/OAI/2.0/oai_dc/
#   METADATA
#   xml  text/xml
#   OAI-PMH Dublin Core v2.0, with online related resource
# application/x-hdf
#   DATA
#   h4   application/x-hdf
#   Hierarchical Data Format version 4 (HDF4)
# application/x-hdf5
#   DATA
#   h5   application/x-hdf5
#   Hierarchical Data Format version 5 (HDF5)
# https://purl.dataone.org/collections-1.0.0
#   METADATA
#   xml  text/xml
#   Dataset collections v1.0.0
# https://purl.dataone.org/portals-1.0.0
#   METADATA
#   xml  text/xml
#   Dataset portals v1.0.0
