# %% [markdown]
# # List Nodes in Production
#
# **Task:** Connect to the DataONE production environment, retrieve the list of nodes, and print out the list.

# %% [markdown]
# First, load the `dataone` R package:

# %%
library(dataone)

# %% [markdown]
# Establish a connection to the CN in production environment:

# %%
client <- D1Client() # See ?CNode for other environments

# %% [markdown]
# List the nodes in that environment with `listNodes`:

# %%
nodes <- listMemberNodes(client)

# %% [markdown]
# Now we can print out the identifiers for each node:

# %%
lapply(nodes, function(node) node@identifier)
# Out:
# [[1]]
# [1] "urn:node:CN"
#
# [[2]]
# [1] "urn:node:CNUNM1"
#
# [[3]]
# [1] "urn:node:CNUCSB1"
#
# [[4]]
# [1] "urn:node:CNORC1"
#
# [[5]]
# [1] "urn:node:KNB"
#
# [[6]]
# [1] "urn:node:ESA"
#
# [[7]]
# [1] "urn:node:SANPARKS"
#
# [[8]]
# [1] "urn:node:ORNLDAAC"
#
# [[9]]
# [1] "urn:node:LTER"
#
# [[10]]
# [1] "urn:node:CDL"
#
# [[11]]
# [1] "urn:node:PISCO"
#
# [[12]]
# [1] "urn:node:ONEShare"
#
# [[13]]
# [1] "urn:node:mnORC1"
#
# [[14]]
# [1] "urn:node:mnUNM1"
#
# [[15]]
# [1] "urn:node:mnUCSB1"
#
# [[16]]
# [1] "urn:node:TFRI"
#
# [[17]]
# [1] "urn:node:USANPN"
#
# [[18]]
# [1] "urn:node:SEAD"
#
# [[19]]
# [1] "urn:node:GOA"
#
# [[20]]
# [1] "urn:node:KUBI"
#
# [[21]]
# [1] "urn:node:LTER_EUROPE"
#
# [[22]]
# [1] "urn:node:DRYAD"
#
# [[23]]
# [1] "urn:node:CLOEBIRD"
#
# [[24]]
# [1] "urn:node:EDACGSTORE"
#
# [[25]]
# [1] "urn:node:IOE"
#
# [[26]]
# [1] "urn:node:US_MPC"
#
# [[27]]
# [1] "urn:node:EDORA"
#
# [[28]]
# [1] "urn:node:RGD"
#
# [[29]]
# [1] "urn:node:GLEON"
#
# [[30]]
# [1] "urn:node:IARC"
#
# [[31]]
# [1] "urn:node:NMEPSCOR"
#
# [[32]]
# [1] "urn:node:TERN"
#
# [[33]]
# [1] "urn:node:NKN"
#
# [[34]]
# [1] "urn:node:USGS_SDC"
#
# [[35]]
# [1] "urn:node:NRDC"
#
# [[36]]
# [1] "urn:node:NCEI"
#
# [[37]]
# [1] "urn:node:PPBIO"
#
# [[38]]
# [1] "urn:node:NEON"
#
# [[39]]
# [1] "urn:node:TDAR"
#
# [[40]]
# [1] "urn:node:ARCTIC"
#
# [[41]]
# [1] "urn:node:BCODMO"
#
# [[42]]
# [1] "urn:node:GRIIDC"
#
# [[43]]
# [1] "urn:node:R2R"
#
# [[44]]
# [1] "urn:node:EDI"
#
# [[45]]
# [1] "urn:node:UIC"
#
# [[46]]
# [1] "urn:node:RW"
#
# [[47]]
# [1] "urn:node:FEMC"
#
# [[48]]
# [1] "urn:node:OTS_NDC"
#
# [[49]]
# [1] "urn:node:PANGAEA"
#
# [[50]]
# [1] "urn:node:ESS_DIVE"
#
# [[51]]
# [1] "urn:node:CAS_CERN"
#
# [[52]]
# [1] "urn:node:FIGSHARE_CARY"
#
# [[53]]
# [1] "urn:node:IEDA_EARTHCHEM"
#
# [[54]]
# [1] "urn:node:IEDA_USAP"
#
# [[55]]
# [1] "urn:node:IEDA_MGDL"
#
# [[56]]
# [1] "urn:node:METAGRIL"
#
# [[57]]
# [1] "urn:node:ARM"
#
# [[58]]
# [1] "urn:node:CA_OPC"
