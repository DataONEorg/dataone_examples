# %% [markdown]
# # List Formats in Production
#
# **Task:** Connect to the DataONE production environment, retrieve the list of Object formats, and print out the list as a table.

# %% [markdown]
# First, load the `dataone` R package:

# %%
library(dataone)

# %% [markdown]
# Establish a connection to the CN in production environment:

# %%
cn <- CNode() # See ?CNode for other environments

# %% [markdown]
# List the formats in that environment with `listFormats`:

# %%
listFormats(cn)
# Out:
#     ID
# 1   eml://ecoinformatics.org/eml-2.0.0
# 2   eml://ecoinformatics.org/eml-2.0.1
# 3   eml://ecoinformatics.org/eml-2.1.0
# 4   eml://ecoinformatics.org/eml-2.1.1
# 5   https://eml.ecoinformatics.org/eml-2.2.0
# 6   http://www.esri.com/metadata/esriprof80.dtd
# 7   FGDC-STD-001.1-1999
# 8   FGDC-STD-001.2-1999
# 9   FGDC-STD-001-1998
# 10  INCITS-453-2009
# 11  http://www.unidata.ucar.edu/namespaces/netcdf/ncml-2.2
# 12  CF-1.0
# 13  CF-1.1
# 14  CF-1.2
# 15  CF-1.3
# 16  CF-1.4
# 17  http://www.cuahsi.org/waterML/1.0/
# 18  http://www.cuahsi.org/waterML/1.1/
# 19  http://www.loc.gov/METS/
# 20  netCDF-3
# 21  netCDF-4
# 22  text/plain
# 23  text/csv
# 24  image/bmp
# 25  image/gif
# 26  image/jp2
# 27  image/jpeg
# 28  image/png
# 29  image/svg+xml
# 30  image/tiff
# ⋮   ⋮
# 105 http://www.icpsr.umich.edu/DDI
# 106 http://purl.org/ornl/schema/mercury/terms/v1.0
# 107 http://datacite.org/schema/kernel-3.0
# 108 http://datacite.org/schema/kernel-3.1
# 109 http://www.nexml.org/2009
# 110 http://ns.dataone.org/metadata/schema/onedcx/v1.0
# 111 http://docs.annotatorjs.org/en/v1.2.x/annotation-format.html
# 112 http://www.isotc211.org/2005/gmd
# 113 http://www.isotc211.org/2005/gmd-noaa
# 114 http://www.isotc211.org/2005/gmd-pangaea
# 115 application/bagit-097
# 116 text/tsv
# 117 application/R
# 118 application/MATLAB
# 119 application/SAS
# 120 application/vnd.google-earth.kmz
# 121 application/MATLAB-v7.3
# 122 application/MATLAB-v7
# 123 application/MATLAB-v6
# 124 application/MATLAB-v4
# 125 application/json
# 126 application/json-ld
# 127 text/markdown
# 128 text/x-rmarkdown
# 129 image/x-raw
# 130 http://www.openarchives.org/OAI/2.0/oai_dc/
# 131 application/x-hdf
# 132 application/x-hdf5
# 133 https://purl.dataone.org/collections-1.0.0
# 134 https://purl.dataone.org/portals-1.0.0
#     Name
# 1   Ecological Metadata Language, version 2.0.0
# 2   Ecological Metadata Language, version 2.0.1
# 3   Ecological Metadata Language, version 2.1.0
# 4   Ecological Metadata Language, version 2.1.1
# 5   Ecological Metadata Language, version 2.2.0
# 6   ESRI Profile of the Content Standard for Digital Geospatial Metadata, March 2003
# 7   Content Standard for Digital Geospatial Metadata, Biological Data Profile, version 001.1-1999
# 8   Content Standard for Digital Geospatial Metadata, Metadata Profile for Shoreline Data, version 001.2-1999
# 9   Content Standard for Digital Geospatial Metadata, version 001-1998
# 10  North American Profile of ISO 19115: 2003 Geographic Information - Metadata
# 11  NetCDF Markup Language, version 2.2
# 12  NetCDF Climate and Forecast Metadata Convention, version 1.0
# 13  NetCDF Climate and Forecast Metadata Convention, version 1.1
# 14  NetCDF Climate and Forecast Metadata Convention, version 1.2
# 15  NetCDF Climate and Forecast Metadata Convention, version 1.3
# 16  NetCDF Climate and Forecast Metadata Convention, version 1.4
# 17  Water Markup Language, version 1.0
# 18  Water Markup Language, version 1.0
# 19  Metadata Encoding and Transmission Standard, version 1
# 20  Network Common Data Format, version 3
# 21  Network Common Data Format, version 4
# 22  Plain Text
# 23  Comma Separated Values Text
# 24  Bitmap Image File
# 25  Graphics Interchange Format
# 26  JPEG 2000
# 27  JPEG
# 28  Portable Network Graphics
# 29  Scalable Vector Graphics
# 30  Tagged Image File Format
# ⋮   ⋮
# 105 Data Documentation Initiative, Codebook version 2.1
# 106 Oak Ridge National Lab Mercury Metadata version 1.0
# 107 DataCite Metadata Schema version 3.0
# 108 DataCite Metadata Schema version 3.1
# 109 NeXML 2009
# 110 DataONE Dublin Core Extended v1.0
# 111 AnnotatorJS 1.2.x Annotation model
# 112 Geographic MetaData (GMD) Extensible Markup Language
# 113 NOAA Variant Geographic MetaData (GMD) Extensible Markup Language
# 114 PANGAEA Variant Geographic MetaData (GMD) Extensible Markup Language
# 115 BagIt File Packaging Format Version 0.97
# 116 Tab Separated Values Text
# 117 R programming language script
# 118 MATLAB programming language script
# 119 SAS programming language script
# 120 Google Earth Keyhole Markup Language (KML) Compressed archive
# 121 Mathworks MATLAB version 7.3 (R2006b or later) binary file - HDF5 compatible
# 122 Mathworks MATLAB version 7 (R14 or later) binary file
# 123 Mathworks MATLAB version 6 (R8 or later) binary file
# 124 Mathworks MATLAB version 4 binary file
# 125 JavaScript Object Notation (JSON) file
# 126 JavaScript Object Notation (JSON) Linked Data file
# 127 Markdown file (pandoc markdown compatible)
# 128 R Markdown file (pandoc markdown compatible)
# 129 RAW digital sensor image file
# 130 OAI-PMH Dublin Core v2.0, with online related resource
# 131 Hierarchical Data Format version 4 (HDF4)
# 132 Hierarchical Data Format version 5 (HDF5)
# 133 Dataset collections v1.0.0
# 134 Dataset portals v1.0.0
#     Type     MediaType                        Extension
# 1   METADATA text/xml                         xml
# 2   METADATA text/xml                         xml
# 3   METADATA text/xml                         xml
# 4   METADATA text/xml                         xml
# 5   METADATA text/xml                         xml
# 6   METADATA text/xml                         xml
# 7   METADATA text/xml                         xml
# 8   METADATA text/xml                         xml
# 9   METADATA text/xml                         xml
# 10  METADATA text/xml                         xml
# 11  METADATA application/netcdf               nc
# 12  DATA     application/netcdf               nc
# 13  DATA     application/netcdf               nc
# 14  DATA     application/netcdf               nc
# 15  DATA     application/netcdf               nc
# 16  DATA     application/netcdf               nc
# 17  METADATA text/xml                         xml
# 18  METADATA text/xml                         xml
# 19  METADATA text/xml                         xml
# 20  DATA     application/netcdf               nc
# 21  DATA     application/netcdf               nc
# 22  DATA     text/plain                       txt
# 23  DATA     text/csv                         csv
# 24  DATA     image/bmp                        bmp
# 25  DATA     image/gif                        gif
# 26  DATA     image/jp2                        jpg
# 27  DATA     image/jpeg                       jpg
# 28  DATA     image/png                        png
# 29  DATA     image/svg+xml                    svg
# 30  DATA     image/tiff                       tiff
# ⋮   ⋮        ⋮                                ⋮
# 105 METADATA text/xml                         xml
# 106 METADATA text/xml                         xml
# 107 METADATA text/xml                         xml
# 108 METADATA text/xml                         xml
# 109 DATA     text/xml                         xml
# 110 METADATA text/xml                         xml
# 111 RESOURCE application/json                 json
# 112 METADATA text/xml                         xml
# 113 METADATA text/xml                         xml
# 114 METADATA text/xml                         xml
# 115 DATA     NA                               NA
# 116 DATA     text/tab-separated-values        tsv
# 117 DATA     text/x-rsrc                      R
# 118 DATA     text/x-matlab                    m
# 119 DATA     text/x-sas                       sas
# 120 DATA     application/vnd.google-earth.kmz kmz
# 121 DATA     application/octet-stream         mat
# 122 DATA     application/octet-stream         mat
# 123 DATA     application/octet-stream         mat
# 124 DATA     application/octet-stream         mat
# 125 DATA     application/json                 json
# 126 DATA     application/ld+json              json
# 127 DATA     text/markdown                    md
# 128 DATA     text/markdown                    Rmd
# 129 DATA     application/octet-stream         raw
# 130 METADATA text/xml                         xml
# 131 DATA     application/x-hdf                h4
# 132 DATA     application/x-hdf5               h5
# 133 METADATA text/xml                         xml
# 134 METADATA text/xml                         xml
